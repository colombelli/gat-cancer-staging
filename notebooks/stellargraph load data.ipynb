# %%
import pandas as pd
from stellargraph import StellarGraph
import numpy as np

base_path = "/home/colombelli/Documents/datasets/acgt/kidney/"
patients_file = base_path + "igraph/patients_corr.csv"
gene_exp_file = base_path + "exp_log2.csv"

# %%
df_patients = pd.read_csv(patients_file, sep=" ", header=None)
df_patients.columns = ["source", "target", "weight"]
df_patients
# Out:
#                source           target    weight
# 0     TCGA.CJ.5672.11  TCGA.CJ.5678.11  0.885394
# 1     TCGA.CJ.5672.11  TCGA.B0.5712.11  0.760276
# 2     TCGA.CJ.5672.11  TCGA.CZ.5458.11  0.866361
# 3     TCGA.CJ.5672.11  TCGA.CW.5580.11  0.888365
# 4     TCGA.CJ.5672.11  TCGA.CZ.5463.11  0.947068
# ...               ...              ...       ...
# 4015  TCGA.CJ.4868.01  TCGA.B0.4700.01  0.743863
# 4016  TCGA.G6.A5PC.01  TCGA.CJ.4638.01  0.785135
# 4017  TCGA.B0.4700.01  TCGA.B0.4712.01  0.754708
# 4018  TCGA.B0.4847.01  TCGA.CZ.5460.01  0.713654
# 4019  TCGA.BP.5201.01  TCGA.CZ.5460.01  0.716853
#
# [4020 rows x 3 columns]

# %%
sg = StellarGraph(edges=df_patients)

# %%
print(sg.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 460, Edges: 4020
#
#  Node types:
#   default: [460]
#     Features: none
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [4020]
#         Weights: range=[0.700023, 0.979342], mean=0.782582, std=0.0775818
#         Features: none

# %%
df_features = pd.read_csv(gene_exp_file, index_col=0)
df_features
# Out:
#                  100130426  100133144  100134869     10357      10431  136542  \
# TCGA.3Z.A93Z.01        0.0   1.985792   3.640031  6.262604   9.141946     0.0
# TCGA.6D.AA2E.01        0.0   1.786638   1.768460  5.662160  10.360348     0.0
# TCGA.A3.3306.01        0.0   2.078815   3.195741  6.155207   9.235935     0.0
# TCGA.A3.3307.01        0.0   1.514905   2.352052  6.579091   9.096268     0.0
# TCGA.A3.3308.01        0.0   2.899949   1.891925  6.503369   9.497138     0.0
# ...                    ...        ...        ...       ...        ...     ...
# TCGA.MM.A563.01        0.0   2.599389   2.164271  6.698138   9.344842     0.0
# TCGA.MM.A564.01        0.0   4.180116   1.994761  6.589819   9.356024     0.0
# TCGA.MM.A84U.01        0.0   1.889162   3.257524  5.979214  10.296157     0.0
# TCGA.MW.A4EC.01        0.0   3.757322   3.231048  6.722952   9.184963     0.0
# TCGA.T7.A92I.01        0.0   2.274381   3.409133  6.196808  10.089904     0.0
#
#                     155060     26823  280660  317712  ...      7789    158586  \
# TCGA.3Z.A93Z.01   6.901573  0.000000     0.0     0.0  ...  5.448108  7.876397
# TCGA.6D.AA2E.01   7.294283  1.056098     0.0     0.0  ...  5.941165  7.907322
# TCGA.A3.3306.01   7.038203  1.352081     0.0     0.0  ...  6.894968  8.839328
# TCGA.A3.3307.01   6.985137  1.503298     0.0     0.0  ...  6.499041  8.843158
# TCGA.A3.3308.01   8.393861  0.939227     0.0     0.0  ...  6.535331  8.642664
# ...                    ...       ...     ...     ...  ...       ...       ...
# TCGA.MM.A563.01   9.042017  1.326250     0.0     0.0  ...  5.788461  8.089354
# TCGA.MM.A564.01  10.089614  0.000000     0.0     0.0  ...  5.662613  8.342945
# TCGA.MM.A84U.01   8.182779  1.088684     0.0     0.0  ...  5.577749  7.922971
# TCGA.MW.A4EC.01   7.833937  0.495695     0.0     0.0  ...  6.346407  8.477799
# TCGA.T7.A92I.01   6.967399  1.319445     0.0     0.0  ...  7.154714  8.747041
#
#                      79364    440590      79699       7791      23140  \
# TCGA.3Z.A93Z.01   9.319576  4.670410   9.339270  11.640547   9.783150
# TCGA.6D.AA2E.01  10.123357  1.389016   9.964891  11.407298  10.644855
# TCGA.A3.3306.01   9.288228  1.025171  10.219161  11.002985  10.102427
# TCGA.A3.3307.01  10.188657  3.529883  10.211163  11.728041  10.028071
# TCGA.A3.3308.01  10.623686  0.939227  10.283732  12.046886  10.748966
# ...                    ...       ...        ...        ...        ...
# TCGA.MM.A563.01  10.137796  5.094481   9.900526  12.125035  10.274012
# TCGA.MM.A564.01   9.349088  0.000000   9.572753  11.558161   9.757998
# TCGA.MM.A84U.01   9.770024  0.644687   9.484809  12.210032  10.270065
# TCGA.MW.A4EC.01   9.387555  2.565743   9.482405  11.736302  10.096719
# TCGA.T7.A92I.01   9.953364  3.729488  10.366513  10.508664  10.761277
#
#                     26009    387590  389932
# TCGA.3Z.A93Z.01  8.948521  5.318035     0.0
# TCGA.6D.AA2E.01  9.912535  8.256968     0.0
# TCGA.A3.3306.01  9.949210  4.000937     0.0
# TCGA.A3.3307.01  9.522393  5.338050     0.0
# TCGA.A3.3308.01  9.845353  3.742728     0.0
# ...                   ...       ...     ...
# TCGA.MM.A563.01  9.274007  6.094589     0.0
# TCGA.MM.A564.01  9.246828  4.932685     0.0
# TCGA.MM.A84U.01  9.102586  9.324181     0.0
# TCGA.MW.A4EC.01  8.927496  4.506678     0.0
# TCGA.T7.A92I.01  8.935997  8.101746     0.0
#
# [606 rows x 20531 columns]

# %%
"""
# Getting the index of the top n genes with the most variance among all genes
n = 500
gene_variances = np.array(df_features.var())
top_genes = gene_variances.argsort()[-n:][::-1]

# Slicing feature dataframe with only the relevant genes
df_features = df_features.iloc[:, top_genes]
"""

# Using the same genes for features as the iqr reduced dataset
df_features = pd.read_csv(base_path+"correlation650.csv", index_col=0).T

# %%
# Getting only the patients present in the graph

df_features = df_features.loc[df_features.index.isin(list(df_patients['source'].values)+list(df_patients['target'].values))]
df_features
# Out:
#                    652919    26154     28         26        40         59272   \
# TCGA.CJ.5672.11  4.760210  3.022403  9.390329  12.063644  5.811021   7.907836
# TCGA.CJ.5678.11  4.870084  4.385183  5.953891  12.566209  5.771725  10.508257
# TCGA.CZ.5458.11  8.751733  5.277181  4.197299
# TCGA.CW.5580.11  8.851669  6.192579  3.663800
# ...                   ...       ...       ...
# TCGA.CZ.5987.01  8.819945  0.000000  0.753861
# TCGA.B4.5377.01  5.590488  1.334625  6.496571
# TCGA.B0.4819.01  6.004358  3.061448  3.143720
# TCGA.B0.4712.01  2.546882  0.526369  4.036653
# TCGA.CJ.4871.01  8.227909  1.341587  2.755678
#
# [460 rows x 650 columns]

# %%
# Testing to make sure that the slicing really considered the top_genes list as indexes for 
# the columns and not the column names itself

7369 in top_genes
# Out:
# False

# %%
# Making StellarGraph object with the features and edges

sg = StellarGraph(df_features, df_patients)
print(sg.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 460, Edges: 4020
#
#  Node types:
#   default: [460]
#     Features: float32 vector, length 650
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [4020]
#         Weights: range=[0.700023, 0.979342], mean=0.782582, std=0.0775818
#         Features: none

# %%
# Getting the cancer staging info

control = pd.read_csv(base_path+"normal.csv", usecols=[0]).iloc[:, 0].values
s1 = pd.read_csv(base_path+"split_stage/stage1.csv", usecols=[0]).iloc[:, 0].values
s2 = pd.read_csv(base_path+"split_stage/stage2.csv", usecols=[0]).iloc[:, 0].values
s3 = pd.read_csv(base_path+"split_stage/stage3.csv", usecols=[0]).iloc[:, 0].values
s4 = pd.read_csv(base_path+"split_stage/stage4.csv", usecols=[0]).iloc[:, 0].values

# %%
# Reformating indexes changing tacks (-) for dots (.) 
control = [i.replace('-','.') for i in control]
s1 = [i.replace('-','.') for i in s1]
s2 = [i.replace('-','.') for i in s2]
s3 = [i.replace('-','.') for i in s3]
s4 = [i.replace('-','.') for i in s4]

# %%
# Building class dataframe with staging information

class_info_dict = {
    "control": control,
    "stage1": s1,
    "stage2": s2,
    "stage3": s3,
    "stage4": s4
}

df_class = pd.DataFrame(columns=['id', 'class'])

for class_info, class_values in class_info_dict.items():
    df_temp = pd.DataFrame({'id': class_values, 'class': [class_info]*len(class_values)})
    df_class = df_class.append(df_temp, ignore_index=True)
       
df_class
# Out:
#                   id    class
# 0    TCGA.CJ.5672.11  control
# 1    TCGA.CJ.5678.11  control
# 2    TCGA.B0.5712.11  control
# 3    TCGA.CZ.5458.11  control
# 4    TCGA.CW.5580.11  control
# ..               ...      ...
# 592  TCGA.B0.4819.01   stage4
# 593  TCGA.B0.4698.01   stage4
# 594  TCGA.B0.4712.01   stage4
# 595  TCGA.B2.5639.01   stage4
# 596  TCGA.CJ.4871.01   stage4
#
# [597 rows x 2 columns]

# %%
# Removing inexistent patients ids based on features dataframe
df_class.set_index('id', inplace=True)
df_class = df_class[df_class.index.isin(df_features.index)]

# %%
df_features.index.name = 'id'

# %%
# Saving the stellargraph processed data for later usage

df_patients.to_csv(base_path+"stellargraph/patients_edges.csv", index=False)
df_features.to_csv(base_path+"stellargraph/patients_features.csv")
df_class.to_csv(base_path+"stellargraph/patients_classes.csv")

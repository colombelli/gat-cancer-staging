# %%
import pandas as pd
from stellargraph import StellarGraph
import numpy as np

base_path = "/home/colombelli/Documents/datasets/acgt/kidney/"
patients_file = base_path + "igraph/patients_corr.csv"

# %%
df_patients = pd.read_csv(patients_file, sep=" ", header=None)
df_patients.columns = ["source", "target", "weight"]
df_patients
# Out:
#                source           target    weight
# 0     TCGA.CJ.5672.11  TCGA.CJ.5672.11  1.000000
# 1     TCGA.CJ.5672.11  TCGA.CJ.5678.11  0.883499
# 2     TCGA.CJ.5672.11  TCGA.B0.5712.11  0.741992
# 3     TCGA.CJ.5672.11  TCGA.CZ.5458.11  0.859380
# 4     TCGA.CJ.5672.11  TCGA.CW.5580.11  0.870693
# ...               ...              ...       ...
# 3613  TCGA.CJ.4887.01  TCGA.CJ.4887.01  1.000000
# 3614  TCGA.CZ.5987.01  TCGA.CZ.5987.01  1.000000
# 3615  TCGA.B4.5377.01  TCGA.B4.5377.01  1.000000
# 3616  TCGA.B0.4712.01  TCGA.B0.4712.01  1.000000
# 3617  TCGA.CJ.4871.01  TCGA.CJ.4871.01  1.000000
#
# [3618 rows x 3 columns]

# %%
sg = StellarGraph(edges=df_patients)

# %%
print(sg.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 429, Edges: 3618
#
#  Node types:
#   default: [429]
#     Features: none
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [3618]
#         Weights: range=[0.700006, 1], mean=0.817409, std=0.100909
#         Features: none

# %%
"""
gene_exp_file = base_path + "exp_log2.csv"
df_features = pd.read_csv(gene_exp_file, index_col=0)

# Getting the index of the top n genes with the most variance among all genes
n = 500
gene_variances = np.array(df_features.var())
top_genes = gene_variances.argsort()[-n:][::-1]

# Slicing feature dataframe with only the relevant genes
df_features = df_features.iloc[:, top_genes]
"""

# Using the same genes for features as the iqr reduced dataset
df_features = pd.read_csv(base_path+"exp_top_500_iqr_all_patients.csv", index_col=0)
#df_features1 = pd.read_csv(base_path+"exp_top_500_iqr.csv", index_col=0)
#df_features2 = pd.read_csv(base_path+"methy_top_100_iqr.csv", index_col=0)
#df_features3 = pd.read_csv(base_path+"mirna_top_100_iqr.csv", index_col=0)
#df_features = pd.concat([df_features1, df_features2, df_features3], axis=1)

# %%
# Getting only the patients present in the graph

df_features = df_features.loc[df_features.index.isin(list(df_patients['source'].values)+list(df_patients['target'].values))]
df_features
# Out:
#                       7503       6192       8653       8284      8287  \
# TCGA.CJ.5672.11   0.647913  11.328816  10.510328   9.445215  9.843287
# TCGA.CJ.5678.11   1.448954  11.826759  10.598356   9.210111  9.629538
# TCGA.B0.5712.11  12.009441   0.000000   0.000000   0.000000  0.000000
# TCGA.CZ.5458.11   0.000000  11.875451  11.824946   9.689907  9.909320
# TCGA.CW.5580.11  12.272338   0.676899   0.377735   0.000000  0.000000
# ...                    ...        ...        ...        ...       ...
# TCGA.CJ.4887.01   2.622368  12.083514  10.568462  10.236086  9.525340
# TCGA.CZ.5987.01   1.613060  12.193709  10.732808   9.622480  9.410406
# TCGA.B4.5377.01  13.203868   0.000000   0.816395   0.000000  0.326192
# TCGA.B0.4712.01   1.320254  12.325243   9.590859   8.256027  7.678599
# TCGA.CJ.4871.01   2.957952  11.070007   9.695498   7.711970  5.507655
#
#                      9086      7404       5340       2173      7544  ...  \
# TCGA.CJ.5672.11  8.717931  9.089266   9.467482   0.695638  8.327877  ...
# TCGA.CJ.5678.11  9.011631  8.673996  12.168129   2.525518  8.490122  ...
# TCGA.B0.5712.11  0.000000  0.000000   8.378272   1.612777  0.000000  ...
# TCGA.CZ.5458.11  9.251469  9.330264   4.587797   1.129613  8.319150  ...
# TCGA.CW.5580.11  0.000000  0.000000   7.035737   0.676899  0.000000  ...
# ...                   ...       ...        ...        ...       ...  ...
# TCGA.CJ.4887.01  8.754824  8.596756   0.529971   5.842207  8.210243  ...
# TCGA.CZ.5987.01  8.947764  8.600273   0.000000  10.877200  8.077061  ...
# TCGA.B4.5377.01  0.000000  0.000000   3.950440   4.574774  0.000000  ...
# TCGA.B0.4712.01  8.809994  7.896880   0.526369  13.620767  8.278706  ...
# TCGA.CJ.4871.01  6.780540  7.323611   8.329460  12.790162  7.696046  ...
#
#                    339855  100131897     10309      3170     81033      55586  \
# TCGA.CJ.5672.11  4.635395   4.772524  5.471529  5.053898  4.580411  11.414323
# TCGA.CJ.5678.11  5.439224   6.142362  3.135141  0.518535  5.983780  13.282498
# TCGA.B0.5712.11  5.313478   4.068757  3.662684  1.020911  2.843019   8.896300
# TCGA.CZ.5458.11  3.908659   3.814345  5.669480  6.474308  0.307545   6.545760
# TCGA.CW.5580.11  5.413032   4.126263  6.069376  3.319040  4.101314  10.269076
# ...                   ...        ...       ...       ...       ...        ...
# TCGA.CJ.4887.01  0.529971   3.648488  0.529971  0.000000  5.960041  10.462171
# TCGA.CZ.5987.01  5.025547   7.247882  3.582737  0.000000  5.025547   9.473051
# TCGA.B4.5377.01  5.927614   7.861759  1.715059  0.592062  7.237677  12.316263
# TCGA.B0.4712.01  3.736540   2.029382  4.705928  5.069737  2.840906   3.915588
# TCGA.CJ.4871.01  0.821465   6.581124  2.910905  4.361958  2.910905   9.218086
#
#                      3975     389434      2861      5968
# TCGA.CJ.5672.11  6.895178   7.841185  4.172999  0.000000
# TCGA.CJ.5678.11  7.188815  10.373635  5.171327  1.661157
# TCGA.B0.5712.11  6.554141   8.041360  6.307775  1.441112
# TCGA.CZ.5458.11  6.366268   5.852661  3.660198  0.000000
# TCGA.CW.5580.11  6.732888   7.562103  3.593999  0.000000
# ...                   ...        ...       ...       ...
# TCGA.CJ.4887.01  0.916630   3.747162  8.197211  4.616134
# TCGA.CZ.5987.01  0.000000   2.698374  7.776477  0.753861
# TCGA.B4.5377.01  0.592062   4.775182  2.476693  0.592062
# TCGA.B0.4712.01  0.526369   1.214747  0.911270  4.251999
# TCGA.CJ.4871.01  0.000000   3.688303  8.540353  5.917797
#
# [429 rows x 500 columns]

# %%
# Testing to make sure that the slicing really considered the top_genes list as indexes for 
# the columns and not the column names itself

#7369 in top_genes

# %%
# Making StellarGraph object with the features and edges

sg = StellarGraph(df_features, df_patients)
print(sg.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 429, Edges: 3618
#
#  Node types:
#   default: [429]
#     Features: float32 vector, length 500
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [3618]
#         Weights: range=[0.700006, 1], mean=0.817409, std=0.100909
#         Features: none

# %%
# Getting the cancer staging info

control = pd.read_csv(base_path+"normal.csv", usecols=[0]).iloc[:, 0].values
s1 = pd.read_csv(base_path+"split_stage/stage1.csv", usecols=[0]).iloc[:, 0].values
s2 = pd.read_csv(base_path+"split_stage/stage2.csv", usecols=[0]).iloc[:, 0].values
s3 = pd.read_csv(base_path+"split_stage/stage3.csv", usecols=[0]).iloc[:, 0].values
s4 = pd.read_csv(base_path+"split_stage/stage4.csv", usecols=[0]).iloc[:, 0].values

# %%
# Reformating indexes changing tacks (-) for dots (.) 
control = [i.replace('-','.') for i in control]
s1 = [i.replace('-','.') for i in s1]
s2 = [i.replace('-','.') for i in s2]
s3 = [i.replace('-','.') for i in s3]
s4 = [i.replace('-','.') for i in s4]

# %%
# Building class dataframe with staging information

class_info_dict = {
    "control": control,
    "stage1": s1,
    "stage2": s2,
    "stage3": s3,
    "stage4": s4
}

df_class = pd.DataFrame(columns=['id', 'class'])

for class_info, class_values in class_info_dict.items():
    df_temp = pd.DataFrame({'id': class_values, 'class': [class_info]*len(class_values)})
    df_class = df_class.append(df_temp, ignore_index=True)
       
df_class
# Out:
#                   id    class
# 0    TCGA.CJ.5672.11  control
# 1    TCGA.CJ.5678.11  control
# 2    TCGA.B0.5712.11  control
# 3    TCGA.CZ.5458.11  control
# 4    TCGA.CW.5580.11  control
# ..               ...      ...
# 592  TCGA.B0.4819.01   stage4
# 593  TCGA.B0.4698.01   stage4
# 594  TCGA.B0.4712.01   stage4
# 595  TCGA.B2.5639.01   stage4
# 596  TCGA.CJ.4871.01   stage4
#
# [597 rows x 2 columns]

# %%
# Removing inexistent patients ids based on features dataframe
df_class.set_index('id', inplace=True)
df_class = df_class[df_class.index.isin(df_features.index)]

# %%
df_features.index.name = 'id'

# %%
# Saving the stellargraph processed data for later usage

df_patients.to_csv(base_path+"stellargraph/patients_edges.csv", index=False)
df_features.to_csv(base_path+"stellargraph/patients_features.csv")
df_class.to_csv(base_path+"stellargraph/patients_classes.csv")
